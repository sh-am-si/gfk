# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

import matplotlib.pylab as plt
from matplotlib_venn import venn3
from venn import venn
import seaborn as sns
sns.set(font_scale=2)
# %matplotlib inline

from utils import prepare_df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = prepare_df(droprows=['period_end_date'])
df.head()
# Out:
#             period_end_date           translated_when  if_data_corrected  \
# 2 2020-09-20 00:00:00+00:00 2020-09-23 12:27:51+00:00                  0
# 3 2020-09-20 00:00:00+00:00 2020-09-23 12:26:41+00:00                  0
# 4 2020-09-20 00:00:00+00:00 2020-09-22 09:40:36+00:00                  0
# 5 2020-09-20 00:00:00+00:00 2020-09-25 15:31:09+00:00                  0
# 6 2020-09-20 00:00:00+00:00 2020-09-22 11:18:00+00:00                  0
#
#    prod_gr_id  country_id_n  delivery_type_id  freq_id  retailer_id  brand_id  \
# 2         426         121.0           42730.0        2           30        37
# 3         426         121.0           42730.0        2           92       203
# 4         426         121.0           50128.0        2            9        31
# 5         426         121.0           19105.0        2          145       205
# 6         427         108.0           47990.0        1          172       237
#
#    predict_automatch  class_acctual
# 2                1.0              1
# 3                1.0              1
# 4                1.0              1
# 5                1.0              1
# 6                1.0              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19640 entries, 2 to 19696
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   period_end_date    19640 non-null  datetime64[ns, UTC]
#  1   translated_when    19640 non-null  datetime64[ns, UTC]
#  2   if_data_corrected  19640 non-null  int64
#  3   prod_gr_id         19640 non-null  int64
#  4   country_id_n       18362 non-null  float64
#  5   delivery_type_id   18362 non-null  float64
#  6   freq_id            19640 non-null  int64
#  7   retailer_id        19640 non-null  int64
#  8   brand_id           19640 non-null  int64
#  9   predict_automatch  19313 non-null  float64
#  10  class_acctual      19640 non-null  int64
# dtypes: datetime64[ns, UTC](2), float64(3), int64(6)
# memory usage: 1.8 MB

# %%
dft = df.set_index('period_end_date')
dft.head()
# Out:
#                                     translated_when  if_data_corrected  \
# period_end_date
# 2020-09-20 00:00:00+00:00 2020-09-23 12:27:51+00:00                  0
# 2020-09-20 00:00:00+00:00 2020-09-23 12:26:41+00:00                  0
# 2020-09-20 00:00:00+00:00 2020-09-22 09:40:36+00:00                  0
# 2020-09-20 00:00:00+00:00 2020-09-25 15:31:09+00:00                  0
# 2020-09-20 00:00:00+00:00 2020-09-22 11:18:00+00:00                  0
#
#                            prod_gr_id  country_id_n  delivery_type_id  \
# period_end_date
# 2020-09-20 00:00:00+00:00         426         121.0           42730.0
# 2020-09-20 00:00:00+00:00         426         121.0           42730.0
# 2020-09-20 00:00:00+00:00         426         121.0           50128.0
# 2020-09-20 00:00:00+00:00         426         121.0           19105.0
# 2020-09-20 00:00:00+00:00         427         108.0           47990.0
#
#                            freq_id  retailer_id  brand_id  predict_automatch  \
# period_end_date
# 2020-09-20 00:00:00+00:00        2           30        37                1.0
# 2020-09-20 00:00:00+00:00        2           92       203                1.0
# 2020-09-20 00:00:00+00:00        2            9        31                1.0
# 2020-09-20 00:00:00+00:00        2          145       205                1.0
# 2020-09-20 00:00:00+00:00        1          172       237                1.0
#
#                            class_acctual
# period_end_date
# 2020-09-20 00:00:00+00:00              1
# 2020-09-20 00:00:00+00:00              1
# 2020-09-20 00:00:00+00:00              1
# 2020-09-20 00:00:00+00:00              1
# 2020-09-20 00:00:00+00:00              1

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19640 entries, 2020-09-20 00:00:00+00:00 to 2020-11-01 00:00:00+00:00
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   translated_when    19640 non-null  datetime64[ns, UTC]
#  1   if_data_corrected  19640 non-null  int64
#  2   prod_gr_id         19640 non-null  int64
#  3   country_id_n       18362 non-null  float64
#  4   delivery_type_id   18362 non-null  float64
#  5   freq_id            19640 non-null  int64
#  6   retailer_id        19640 non-null  int64
#  7   brand_id           19640 non-null  int64
#  8   predict_automatch  19313 non-null  float64
#  9   class_acctual      19640 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(3), int64(6)
# memory usage: 1.6 MB

# %%
dft.columns
# Out:
# Index(['translated_when', 'if_data_corrected', 'prod_gr_id', 'country_id_n',
#        'delivery_type_id', 'freq_id', 'retailer_id', 'brand_id',
#        'predict_automatch', 'class_acctual'],
#       dtype='object')

# %%
for column in ['delivery_type_id', 'predict_automatch', 'country_id_n']:
    fig = plt.figure(figsize=(8,8))
    ax = fig.gca()
    ax.set_title(column)
    dft[column].resample('WeekDay').apply(lambda x: np.sum(pd.isna(x))).plot(subplots=True, figsize=(4,4), ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets._get_offset()
#
# KeyError: 'WEEKDAY'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets.to_offset()
#
# pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets._get_offset()
#
# ValueError: Invalid frequency: WEEKDAY
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-2666667d42d7> in <module>
#       3     ax = fig.gca()
#       4     ax.set_title(column)
# ----> 5     dft[column].resample('WeekDay').apply(lambda x: np.sum(pd.isna(x))).plot(subplots=True, figsize=(4,4), ax=ax)
#       6 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8367
#    8368         axis = self._get_axis_number(axis)
# -> 8369         return get_resampler(
#    8370             self,
#    8371             freq=rule,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    1308     Create a TimeGrouper and return our resampler.
#    1309     """
# -> 1310     tg = TimeGrouper(**kwds)
#    1311     return tg._get_resampler(obj, kind=kind)
#    1312
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/resample.py in __init__(self, freq, closed, label, how, axis, fill_method, limit, loffset, kind, convention, base, origin, offset, **kwargs)
#    1379             raise ValueError(f"Unsupported value {convention} for `convention`")
#    1380
# -> 1381         freq = to_offset(freq)
#    1382
#    1383         end_types = {"M", "A", "Q", "BM", "BA", "BQ", "W"}
#
# pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets.to_offset()
#
# pandas/_libs/tslibs/offsets.pyx in pandas._libs.tslibs.offsets.to_offset()
#
# ValueError: Invalid frequency: WeekDay

# %%
fig, axes = plt.subplots(7, 1, figsize=(10, 40), sharex=True)
for col, ax in zip(['if_data_corrected', 'prod_gr_id', 'country_id_n',
       'delivery_type_id', 'freq_id', 'retailer_id', 'brand_id'], axes):
    sns.boxplot(data=dft, x='if_data_corrected', y=col, ax=ax)
    ax.set_ylabel('')
    ax.set_title(col)

    if ax != axes[-1]:
        ax.set_xlabel('')

# %%
dft.resample('D').mean().plot( y='freq_id')
# Out:
# <AxesSubplot:xlabel='period_end_date'>
